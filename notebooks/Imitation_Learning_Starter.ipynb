# %% [markdown]
# # Imitation Learning Starter\nThis notebook demonstrates how to load the generated CSV and prepare state-action pairs.

# %%
import pandas as pd\ndf = pd.read_csv('../backend/data/mlbb_dataset.csv')\ndf.head()
